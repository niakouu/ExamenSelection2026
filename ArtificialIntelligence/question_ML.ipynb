# %% [markdown]
# ## Le chien a mangé les intras?
# Le prof de INF1015 a la belle habitude de corriger les intras des élèves de deuxième année en avance. Cependant, exceptionnellement, cette année, il décide de se prendre à la dernière minute. Avec le stress du département de génie logiciel/informatique et les étudiants énervés sur Discord, le prof se perd dans ses fichiers et perd les intras de 10 étudiants!
#
# Votre tâche est de déterminer si les étudiants qui ont perdu leurs intras ont réussi ou échoué l'intra, en utilisant le jeu de données disponible qui comprend plus de 500 étudiants.
# Vous devez prédire la colonne `passed` dans le fichier `our_students.csv`

# %% [markdown]
# Importation des librairies et des données :

# %%
import pandas as pd
import numpy as np
# Librairies de ML recommandées
# from sklearn.model_selection import train_test_split
# from xgboost import XGBClassifier

data_set_etudiants = pd.read_csv("sample_students.csv")
etudiants_a_predire = pd.read_csv("our_students.csv")

# %% [markdown]
# Quelques informations supplémentaires :

# %%
print("Nombre d'étudiants dans le jeu de données:", len(data_set_etudiants))
print("Nombre d'étudiants à prédire:", len(etudiants_a_predire))
print("Types de données:", data_set_etudiants.dtypes.to_dict())
# Pour rendre la tâche plus facile, les catégories international, does_smoke, does_homework, has_stress sont encodées en 0 et 1
# Il faut prédire la colonne 'passed' soit 0 (échoué) ou 1 (réussi)
# Out:
# Nomre d'etudiants dans le jeu de donnees: 500
# Nomre d'etudiants a predire: 10
# Types de donnees: {'international': dtype('int64'), 'hours_study': dtype('float64'), 'missed_classes': dtype('int64'), 'gpa': dtype('float64'), 'showers_per_week': dtype('int64'), 'does_smoke': dtype('int64'), 'does_homework': dtype('int64'), 'has_stress': dtype('int64'), 'avg_sleep': dtype('float64'), 'confidence': <StringDtype(storage='python', na_value=nan)>, 'passed': dtype('int64')}

# %% [markdown]
# Bonne chance!

# %%
# Commencez votre code ici
